# %% [markdown]
# # فى شويه مشاكل فى الاكسبرت سيستم الاصلى فى الرن

# %%
from experta import *
from tkinter import *

# %%
class CoworkingSpace(KnowledgeEngine):
    @DefFacts()
    def _intialize(self):
        gui_form1 = Tk()
        gui_form1.title("SkipTimes Coworking Space Expert System")
#         gui_form1.geometry("800x500")
        lb0 = Label(gui_form1,text="Hello now you can book a Course or Room \n let's try",bg="#123456", fg="#fff",width="800")
        lb0.pack()
        
###############################################################################
        lb1 = Label(gui_form1,text="Do you want to book a Course?")
        en1 = Entry(gui_form1)
        lb1.pack()
        en1.pack()
###############################################################################
        lb2 = Label(gui_form1,text="Do you want book a Room?")
        en2 = Entry(gui_form1)
        lb2.pack()
        en2.pack()
###############################################################################
        lb3 = Label(gui_form1,text="Do you want to sign up as a startup?")
        en3 = Entry(gui_form1)
        lb3.pack()
        en3.pack()
###############################################################################
        lb4 = Label(gui_form1,text="Do you want to reserve Table?")
        en4 = Entry(gui_form1)
        lb4.pack()
        en4.pack()
###############################################################################
        lb5 = Label(gui_form1,text="Do you want to reserve Room?")
        en5 = Entry(gui_form1)
        lb5.pack()
        en5.pack()
###############################################################################
        lb6 = Label(gui_form1,text="Do you want to sign up as a person?")
        en6 = Entry(gui_form1)
        lb6.pack()
        en6.pack()
##############################################################################
        lb7 = Label(gui_form1,text="Do you want to reserve a meeting room?")
        en7 = Entry(gui_form1)
        lb7.pack()
        en7.pack()
###############################################################################
        lb8 = Label(gui_form1,text="Do you want to have a Group meeting?")
        en8 = Entry(gui_form1)
        lb8.pack()
        en8.pack()
###############################################################################
        lb9 = Label(gui_form1,text="Do you want to have a 1 to 1 meeting?")
        en9 = Entry(gui_form1)
        lb9.pack()
        en9.pack()
###############################################################################
        lb10 = Label(gui_form1,text="Do you want to relax?")
        en10 = Entry(gui_form1)
        lb10.pack()
        en10.pack()
###############################################################################
        lb11 = Label(gui_form1,text="Do you want to reserve a Work room?")
        en11 = Entry(gui_form1)
        lb11.pack()
        en11.pack()
##############################################################################
        lb12 = Label(gui_form1,text="Do you want Shared Room room?")
        en12 = Entry(gui_form1)
        lb12.pack()
        en12.pack()
##############################################################################
        lb13 = Label(gui_form1,text="Do you want Private room?")
        en13 = Entry(gui_form1)
        lb13.pack()
        en13.pack()
###############################################################################
        lb14 = Label(gui_form1,text="Do you want programming course?")
        en14 = Entry(gui_form1)
        lb14.pack()
        en14.pack()
###############################################################################
        lb15 = Label(gui_form1,text="Do you want Mobile course?")
        en15 = Entry(gui_form1)
        lb15.pack()
        en15.pack()
##############################################################################
        lb16 = Label(gui_form1,text="Do you want Native course?")
        en16 = Entry(gui_form1)
        lb16.pack()
        en16.pack()
###############################################################################
        lb16 = Label(gui_form1,text="Do you want Data Science course?")
        en16 = Entry(gui_form1)
        lb16.pack()
        en16.pack()
###############################################################################
        lb17 = Label(gui_form1,text="Do you want Web course?")
        en17 = Entry(gui_form1)
        lb17.pack()
        en17.pack()
###############################################################################
        lb18 = Label(gui_form1,text="Do you want Design course?")
        en18 = Entry(gui_form1)
        lb18.pack()
        en18.pack()
###############################################################################
        lb19 = Label(gui_form1,text="Do you want Language course?")
        en19 = Entry(gui_form1)
        lb19.pack()
        en19.pack()
###############################################################################
        lb20 = Label(gui_form1,text="English")
        en20 = Entry(gui_form1)
        lb20.pack()
        en20.pack()
##############################################################################
        lb21 = Label(gui_form1,text="German")
        en21 = Entry(gui_form1)
        lb21.pack()
        en21.pack()
###############################################################################
        lb23 = Label(gui_form1,text="Startup")
        en23 = Entry(gui_form1)
        lb23.pack()
        en23.pack()
###############################################################################
        lb24 = Label(gui_form1,text="Person")
        en24 = Entry(gui_form1)
        lb24.pack()
        en24.pack()
###############################################################################
        lb25 = Label(gui_form1,text="Table")
        en25 = Entry(gui_form1)
        lb25.pack()
        en25.pack()
###############################################################################
        lb26 = Label(gui_form1,text="Room")
        en26 = Entry(gui_form1)
        lb26.pack()
        en26.pack()
##############################################################################
        lb27 = Label(gui_form1,text="Meeting")
        en27 = Entry(gui_form1)
        lb27.pack()
        en27.pack()
###############################################################################
        lb28 = Label(gui_form1,text="Work")
        en28 = Entry(gui_form1)
        lb28.pack()
        en28.pack()
#############################################################################
        lb29 = Label(gui_form1,text="Relaxation")
        en29 = Entry(gui_form1)
        lb29.pack()
        en29.pack()
###############################################################################
        lb30 = Label(gui_form1,text="1 to 1")
        en30 = Entry(gui_form1)
        lb30.pack()
        en30.pack()
###############################################################################
        lb31 = Label(gui_form1,text="Group up to 10")
        en31 = Entry(gui_form1)
        lb31.pack()
        en31.pack()
###############################################################################
        lb32 = Label(gui_form1,text="Private")
        en32 = Entry(gui_form1)
        lb32.pack()
        en32.pack()
###############################################################################
        lb33 = Label(gui_form1,text="Shared room")
        en33 = Entry(gui_form1)
        lb33.pack()
        en33.pack()
###############################################################################       
        def get_values():
            #lb2["text"] = en2.get()
            self.declare(Fact(Course=en1.get()))
            self.declare(Fact(Rooms=en2.get()))
            self.declare(Fact(Programming=en3.get()))
            self.declare(Fact(Web=en4.get()))
            self.declare(Fact(Mobile=en5.get()))
            self.declare(Fact(Data_Science=en6.get()))
            self.declare(Fact(Frontend=en7.get()))
            self.declare(Fact(Backend=en8.get()))
            self.declare(Fact(Cross_platform=en9.get()))
            self.declare(Fact(Native=en10.get()))
            self.declare(Fact(Android=en11.get()))
            self.declare(Fact(IOS=en12.get()))
            self.declare(Fact(ML=en13.get()))
            self.declare(Fact(Data_Analysis=en14.get()))
            self.declare(Fact(Design=en15.get()))
            self.declare(Fact(UI=en16.get()))
            self.declare(Fact(Graphic_Design=en17.get()))
            self.declare(Fact(Motion_Graphics=en18.get()))
            self.declare(Fact(Language=en19.get()))
            self.declare(Fact(English=en20.get()))
            self.declare(Fact(German=en21.get()))
            self.declare(Fact(Spanish=en22.get()))
            self.declare(Fact(Startup=en23.get()))
            self.declare(Fact(Person=en24.get()))
            self.declare(Fact(Table=en25.get()))
            self.declare(Fact(Room=en26.get()))
            self.declare(Fact(Meeting=en27.get()))
            self.declare(Fact(Work=en28.get()))
            self.declare(Fact(Relaxation=en29.get()))
            self.declare(Fact(one2one=en30.get()))
            self.declare(Fact(Group=en31.get()))
            self.declare(Fact(Private=en32.get()))
            self.declare(Fact(Shared_Room=en33.get()))

#############################################################################
        btn = Button(gui_form1,command=get_values,text="get_values",bg="#123456", fg="#fff")
        btn.pack()
        
        
        gui_form1.mainloop()
        yield Fact(action = "find_book")

###############################################################################################

@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Web = 'yes'), (Fact(Frontend = 'yes')))
def value11(self):
    self.declare(Fact(res='React'))

@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Web = 'yes'), (Fact(Backend = 'yes')))
def value12(self):
    self.declare(Fact(res='Dijango or node'))

#######################################################################################################################
@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Mobile = 'yes'), Fact(Cross_platform = 'yes'))
def value13(self):
    self.declare(Fact(res='Flutter'))

#############
@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Mobile = 'yes'), Fact(Native = 'yes'), Fact(Andriod = 'yes'))
def value17(self):
    self.declare(Fact(res='Kotlin'))

@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Mobile = 'yes'), Fact(Native = 'yes'), Fact(IOS = 'yes'))
def value18(self):
    self.declare(Fact(res='SWIFT'))

@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Data_Science = 'yes'), (Fact(ML = 'yes')))
def value21(self):
    self.declare(Fact(res='Build models using TensorFlow and Pytorch'))
@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Data_Science = 'yes'), (Fact(Data_Analysis = 'yes')))
def value22(self):
    self.declare(Fact(res="Show Data insights using Python, SQL, Excel and Power BI**"))


###########################################################################################################

@Rule(Fact(Course = 'yes'), Fact(Design = 'yes'), Fact(UI = 'yes'))
def value26(self):
    self.declare(Fact(res='Figma'))
@Rule(Fact(Course = 'yes'), Fact(Design = 'yes'), Fact(Graphic_Design = 'yes'))
def value27(self):
    self.declare(Fact(res="**You will use adobe products like Photoshop and Illistrator to create Graphic Designs**"))

@Rule(Fact(Course = 'yes'), Fact(Design = 'yes'), Fact(Motion_Graphics = 'yes'))
def value28(self):
    self.declare(Fact(res="**Use After Effects to create motion graphics**"))

#########################################################################################################

@Rule(Fact(Course = 'yes'), Fact(Language = 'yes'), Fact(English = 'yes'))
def value32(self):
    self.declare(Fact(res="**From Beginner to Advanced in English in no time**"))

@Rule(Fact(Course = 'yes'), Fact(Language = 'yes'), Fact(German = 'yes'))
def value33(self):
    self.declare(Fact(res="**Best Education is in Germany**"))

@Rule(Fact(Course = 'yes'), Fact(Language = 'yes'), Fact(Spanish = 'yes'))
def value34(self):
    self.declare(Fact(res="**Spanish is cool language**"))

###############################################################################################
@Rule(Fact(Rooms = 'yes'), Fact(Startup = 'yes'), Fact(Table = 'yes'))
def value39(self):
    self.declare(Fact(res='**Room 5 contains our best Tables for you**'))

@Rule(Fact(Rooms = 'yes'), Fact(Startup = 'yes'), Fact(Room = 'yes'))
def value40(self):
    self.declare(Fact(res='**Room 4 and Room 6 are created to suit your work**'))

#################################################################################################
@Rule(Fact(Rooms = 'yes'), Fact(Person = 'yes'), Fact(Relaxation = 'yes'))
def value44(self):
    self.declare(Fact(res='**You can relax in our Cafe or Relaxation room**'))

####################################################################################################
@Rule(Fact(Rooms = 'yes'), Fact(Person = 'yes'), Fact(Meeting = 'yes'), Fact(one2one = 'yes'))
def value47(self):
    self.declare(Fact(res='**Room 6 is great for one to one meeting**'))

@Rule(Fact(Rooms = 'yes'), Fact(Person = 'yes'), Fact(Meeting = 'yes'), Fact(Group = 'yes'))
def value48(self):
    self.declare(Fact(res='**Room 5 and Room 6 contains all you need for your team**'))

#######################################################################################################
@Rule(Fact(Rooms = 'yes'), Fact(Person = 'yes'), Fact(Work = 'yes'), Fact(Private = 'yes'))
def value51(self):
    self.declare(Fact(res='Room 3 is great to relax while working in private environment'))

@Rule(Fact(Rooms = 'yes'), Fact(Person = 'yes'), Fact(Work = 'yes'), Fact(Shared_Room = 'yes'))
def value52(self):
    self.declare(Fact(res='Room 1 and Room 2 have been created to work together on shared rooms'))
    
    @Rule(Fact(action='find_book'),Fact(res=MATCH.disease))
    def res(self, res):
        print("")
        id_res = res
        gui_form2 = Tk()
        gui_form2.title("SkipTimes Coworking Space Expert System")
        #gui_form2.geometry("800x500")
        lb0 = Label(gui_form1,gui_form2,text="Your choice",bg="#123456", fg="#fff",width="800")
        lb0.pack()
        var = StringVar()
        var.set(id_res)
        lb1 = Label(gui_form1,gui_form2,textvariable = var,bg="#678954", fg="#fff",width="800")
        lb1.pack()
        #print("The most probable disease that you have is %s\n" %(id_disease))
        gui_form2.mainloop()
        
engine = CoworkingSpace()
while(1):
    engine.reset()  # Prepare the engine for the execution.
    engine.run()  # Run it!
    print("Do you want to run app again?")
    if input() == "no":
        break;
# Out:
# Do you want to run app again?
# no

# %% [markdown]
# # محاوله تقليل الاسئله شويه

# %%
class CoworkingSpace(KnowledgeEngine):
    @DefFacts()
    def _intialize(self):
        gui_form1 = Tk()
        gui_form1.title("SkipTimes Coworking Space Expert System")
#         gui_form1.geometry("800x500")
        lb0 = Label(gui_form1,text="Hello now you can book a Course or Room \n let's try",bg="#123456", fg="#fff",width="800")
        lb0.pack()
        
###############################################################################
        lb1 = Label(gui_form1,text="Do you want to book a Course?")
        en1 = Entry(gui_form1)
        lb1.pack()
        en1.pack()
###############################################################################
        lb2 = Label(gui_form1,text="Do you want book a Room?")
        en2 = Entry(gui_form1)
        lb2.pack()
        en2.pack()
###############################################################################
        lb3 = Label(gui_form1,text="Do you want to sign up as a startup?")
        en3 = Entry(gui_form1)
        lb3.pack()
        en3.pack()
###############################################################################
        lb4 = Label(gui_form1,text="Do you want to reserve Table?")
        en4 = Entry(gui_form1)
        lb4.pack()
        en4.pack()
###############################################################################
        lb5 = Label(gui_form1,text="Do you want to reserve Room?")
        en5 = Entry(gui_form1)
        lb5.pack()
        en5.pack()
###############################################################################
        lb6 = Label(gui_form1,text="Do you want to sign up as a person?")
        en6 = Entry(gui_form1)
        lb6.pack()
        en6.pack()
##############################################################################
        lb7 = Label(gui_form1,text="Do you want to reserve a meeting room?")
        en7 = Entry(gui_form1)
        lb7.pack()
        en7.pack()
###############################################################################
        lb8 = Label(gui_form1,text="Do you want to have a Group meeting?")
        en8 = Entry(gui_form1)
        lb8.pack()
        en8.pack()
###############################################################################
        lb9 = Label(gui_form1,text="Do you want to have a 1 to 1 meeting?")
        en9 = Entry(gui_form1)
        lb9.pack()
        en9.pack()
###############################################################################
        lb10 = Label(gui_form1,text="Do you want to relax?")
        en10 = Entry(gui_form1)
        lb10.pack()
        en10.pack()
###############################################################################
        lb11 = Label(gui_form1,text="Do you want to reserve a Work room?")
        en11 = Entry(gui_form1)
        lb11.pack()
        en11.pack()
##############################################################################
        lb12 = Label(gui_form1,text="Do you want Shared Room room?")
        en12 = Entry(gui_form1)
        lb12.pack()
        en12.pack()
##############################################################################
        lb13 = Label(gui_form1,text="Do you want Private room?")
        en13 = Entry(gui_form1)
        lb13.pack()
        en13.pack()
###############################################################################
        lb14 = Label(gui_form1,text="Do you want programming course?")
        en14 = Entry(gui_form1)
        lb14.pack()
        en14.pack()
###############################################################################
        lb15 = Label(gui_form1,text="Do you want Mobile course?")
        en15 = Entry(gui_form1)
        lb15.pack()
        en15.pack()
###############################################################################
        lb16 = Label(gui_form1,text="Do you want Data Science course?")
        en16 = Entry(gui_form1)
        lb16.pack()
        en16.pack()
###############################################################################
        lb17 = Label(gui_form1,text="Do you want Web course?")
        en17 = Entry(gui_form1)
        lb17.pack()
        en17.pack()
###############################################################################       
        def get_values():
            #lb2["text"] = en2.get()
            self.declare(Fact(Course=en1.get()))
            self.declare(Fact(Rooms=en2.get()))
            self.declare(Fact(Startup=en3.get()))
            self.declare(Fact(Table=en4.get()))
            self.declare(Fact(Room=en5.get()))
            self.declare(Fact(Person=en6.get()))
            self.declare(Fact(Meeting=en7.get()))
            self.declare(Fact(Group=en8.get()))
            self.declare(Fact(one2one=en9.get()))
            self.declare(Fact(Relaxation=en10.get()))
            self.declare(Fact(Work=en11.get()))
            self.declare(Fact(Shared=en12.get()))
            self.declare(Fact(Private=en13.get()))
            self.declare(Fact(Programming=en14.get()))
            self.declare(Fact(Mobile=en15.get()))
            self.declare(Fact(Data_Science=en16.get()))
            self.declare(Fact(Web=en17.get()))
            
#############################################################################
        btn = Button(gui_form1,command=get_values,text="get_values",bg="#123456", fg="#fff")
        btn.pack()
        
        
        gui_form1.mainloop()
        yield Fact(action = "find_book")

###############################################################################################

@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Web = 'yes'))
def value11(self):
    self.declare(Fact(res='React for front, Dijango or node for back'))

#######################################################################################################################
@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Mobile = 'yes'))
def value13(self):
    self.declare(Fact(res='Flutter'))

#############
@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Mobile = 'yes'))
def value17(self):
    self.declare(Fact(res='Kotlin'))

@Rule(Fact(Course = 'yes'), Fact(Programming = 'yes'), Fact(Data_Science = 'yes'))
def value21(self):
    self.declare(Fact(res='Build models using TensorFlow and Pytorch'))


###############################################################################################
@Rule(Fact(Rooms = 'yes'), Fact(Startup = 'yes'), Fact(Table = 'yes'))
def value39(self):
    self.declare(Fact(res='**Room 5 contains our best Tables for you**'))

@Rule(Fact(Rooms = 'yes'), Fact(Startup = 'yes'), Fact(Room = 'yes'))
def value40(self):
    self.declare(Fact(res='**Room 4 and Room 6 are created to suit your work**'))

#################################################################################################
@Rule(Fact(Rooms = 'yes'), Fact(Person = 'yes'), Fact(Relaxation = 'yes'))
def value44(self):
    self.declare(Fact(res='**You can relax in our Cafe or Relaxation room**'))

####################################################################################################
@Rule(Fact(Rooms = 'yes'), Fact(Person = 'yes'), Fact(Meeting = 'yes'), Fact(one2one = 'yes'))
def value47(self):
    self.declare(Fact(res='**Room 6 is great for one to one meeting**'))

@Rule(Fact(Rooms = 'yes'), Fact(Person = 'yes'), Fact(Meeting = 'yes'), Fact(Group = 'yes'))
def value48(self):
    self.declare(Fact(res='**Room 5 and Room 6 contains all you need for your team**'))

#######################################################################################################
@Rule(Fact(Rooms = 'yes'), Fact(Person = 'yes'), Fact(Work = 'yes'), Fact(Private = 'yes'))
def value51(self):
    self.declare(Fact(res='Room 3 is great to relax while working in private environment'))

@Rule(Fact(Rooms = 'yes'), Fact(Person = 'yes'), Fact(Work = 'yes'), Fact(Shared_Room = 'yes'))
def value52(self):
    self.declare(Fact(res='Room 1 and Room 2 have been created to work together on shared rooms'))
    
    @Rule(Fact(action='find_book'),Fact(res=MATCH.disease))
    def res(self, res):
        print("")
        id_res = res
        gui_form2 = Tk()
        gui_form2.title("SkipTimes Coworking Space Expert System")
        #gui_form2.geometry("800x500")
        lb0 = Label(gui_form1,gui_form2,text="Your choice",bg="#123456", fg="#fff",width="800")
        lb0.pack()
        var = StringVar()
        var.set(id_res)
        lb1 = Label(gui_form1,gui_form2,textvariable = var,bg="#678954", fg="#fff",width="800")
        lb1.pack()
        print("Your selection %s\n" %(id_res))
        gui_form2.mainloop()
        
engine = CoworkingSpace()
while(1):
    engine.reset()  # Prepare the engine for the execution.
    engine.run()  # Run it!
    print("Do you want to run app again?")
    if input() == "no":
        break;
# Out:
# WARNING:experta.watchers.ENGINE:Declaring fact before reset()
# Do you want to run app again?
# no

# %% [markdown]
# # سيستم شغال معمول

# %%
from tkinter import *
from experta import *

#create inference engine
class eye_diesease(KnowledgeEngine):
    @DefFacts()
    def _initial_action(self):
        gui_form1 = Tk() #user interface
        gui_form1.title("eye dieseases")
        lb0 = Label(gui_form1,text="Welcome to our Eye Disease Diagnosis Expert System. Our system is designed to help you \n understand your eye symptoms and provide you with accurate information about your eye health.\nFor that you'll have to answer a few questions about your conditions \Do you feel any of the following symptoms::",bg="#123456", fg="#fff",width="800")
        lb0.pack()
###############################################################################
        lb1 = Label(gui_form1,text="1- Do you have redness in your eyes? (yes/no)")
        en1 = Entry(gui_form1)
        lb1.pack()
        en1.pack()
###############################################################################
        lb2 = Label(gui_form1,text="2- Do you have itching in your eyes? (yes/no)")
        en2 = Entry(gui_form1)
        lb2.pack()
        en2.pack()
###############################################################################
        lb3 = Label(gui_form1,text="3- Do you have pain in your eyes? (yes/no)")
        en3 = Entry(gui_form1)
        lb3.pack()
        en3.pack()
###############################################################################
        lb4 = Label(gui_form1,text="4- Do you have blurred vision? (yes/no)")
        en4 = Entry(gui_form1)
        lb4.pack()
        en4.pack()
###############################################################################
        lb5 = Label(gui_form1,text="5- Do you have double vision? (yes/no)")
        en5 = Entry(gui_form1)
        lb5.pack()
        en5.pack()
###############################################################################
        lb6 = Label(gui_form1,text="6- Do you have headache? (yes/no)")
        en6 = Entry(gui_form1)
        lb6.pack()
        en6.pack()
###############################################################################
        lb7 = Label(gui_form1,text="7- Do you have dryness in your eyes? (yes/no)")
        en7 = Entry(gui_form1)
        lb7.pack()
        en7.pack()
###############################################################################
        lb8 = Label(gui_form1,text="8- Do you have burning sensation in your eyes? (yes/no):")
        en8 = Entry(gui_form1)
        lb8.pack()
        en8.pack()
###############################################################################
        lb9 = Label(gui_form1,text="9- Do you have tearing in your eyes? (yes/no):")
        en9 = Entry(gui_form1)
        lb9.pack()
        en9.pack()
###############################################################################
        lb10 = Label(gui_form1,text="10- Are you sensitive to light? (yes/no)")
        en10 = Entry(gui_form1)
        lb10.pack()
        en10.pack()
#############################################################################
        lb11 = Label(gui_form1,text="11- Have you experienced a decrease in your vision? (yes/no)")
        en11= Entry(gui_form1)
        lb11.pack()
        en11.pack()
###############################################################################
        lb12 = Label(gui_form1,text="12- Do you have a blind spot in your vision? (yes/no):")
        en12 = Entry(gui_form1)
        lb12.pack()
        en12.pack()
##############################################################################
        def get_values():
            self.declare(Fact(redness=en1.get()))
            self.declare(Fact(itching=en2.get()))
            self.declare(Fact(pain=en3.get()))
            self.declare(Fact(blurred_vision=en4.get()))
            self.declare(Fact(doubled_vision=en5.get()))
            self.declare(Fact(headache=en6.get()))
            self.declare(Fact(dryness=en7.get()))
            self.declare(Fact(burning_sensation=en8.get()))
            self.declare(Fact(tearing=en9.get()))
            self.declare(Fact(sensitivity_to_light=en10.get()))
            self.declare(Fact(decreased_vision=en11.get()))
            self.declare(Fact(blind_spot=en12.get()))
#############################################################################
        btn = Button(gui_form1,command=get_values,text="get_values",bg="#123456", fg="#fff")
        btn.pack()
            
        gui_form1.mainloop()
        yield Fact(action="eye_disease")
        
###################################################################################################
##################################################################################################
    #knowlege base
    @Rule(Fact(action='eye_disease'),Fact(rednees="yes"),Fact(itching="yes"),Fact(pain="yes"),Fact(blurred_vision="no"),Fact(double_vision="no"),Fact(headache="no"),Fact(dryness="no"),Fact(burning_sensation="no"),Fact(tearing="no"),Fact(sensitivity_to_light="no"),Fact(decreased_vision="no"),Fact(blind_spot="no"))
    def disease_0(self):
         
        self.declare(Fact(disease="You may have Conjunctivitis. Please see an eye specialist for further diagnosis."))

    @Rule(Fact(action='eye_disease'),Fact(rednees="no"),Fact(itching="no"),Fact(pain="no"),Fact(blurred_vision="yes"),Fact(double_vision="yes"),Fact(headache="yes"),Fact(dryness="no"),Fact(burning_sensation="no"),Fact(tearing="no"),Fact(sensitivity_to_light="no"),Fact(decreased_vision="no"),Fact(blind_spot="no"))
    def disease_1(self):
        self.declare(Fact(disease="You may have Astigmatism. Please see an eye specialist for further diagnosis."))

    @Rule(Fact(action='eye_disease'),Fact(rednees="yes"),Fact(itching="no"),Fact(pain="no"),Fact(blurred_vision="no"),Fact(double_vision="no"),Fact(headache="no"),Fact(dryness="no"),Fact(burning_sensation="no"),Fact(tearing="yes"),Fact(sensitivity_to_light="no"),Fact(decreased_vision="no"),Fact(blind_spot="no"))
    def disease_2(self):
        self.declare(Fact(disease="You may have Dry Eye Syndrome. Please see an eye specialist for further diagnosis"))
        
    @Rule(Fact(action='eye_disease'),Fact(rednees="yes"),Fact(itching="yes"),Fact(pain="yes"),Fact(blurred_vision="yes"),Fact(double_vision="no"),Fact(headache="no"),Fact(dryness="no"),Fact(burning_sensation="no"),Fact(tearing="no"),Fact(sensitivity_to_light="no"),Fact(decreased_vision="no"),Fact(blind_spot="no"))
    def disease0(self):
         
        self.declare(Fact(disease="You may have Corneal Abrasion. Please see an eye specialist for further diagnosis"))

    @Rule(Fact(action='eye_disease'),Fact(rednees="no"),Fact(itching="no"),Fact(pain="no"),Fact(blurred_vision="yes"),Fact(double_vision="yes"),Fact(headache="yes"),Fact(dryness="yes"),Fact(burning_sensation="no"),Fact(tearing="no"),Fact(sensitivity_to_light="no"),Fact(decreased_vision="no"),Fact(blind_spot="no"))
    def disease1(self):
        self.declare(Fact(disease="You may have Cataracts. Please see an eye specialist for further diagnosis."))     
        
    @Rule(Fact(action='eye_disease'),Fact(rednees="no"),Fact(itching="no"),Fact(pain="no"),Fact(blurred_vision="no"),Fact(double_vision="no"),Fact(headache="no"),Fact(dryness="no"),Fact(burning_sensation="no"),Fact(tearing="no"),Fact(sensitivity_to_light="no"),Fact(decreased_vision="yes"),Fact(blind_spot="yes"))
    def disease_5(self):
         
        self.declare(Fact(disease="You may have Glaucoma. Please see an eye specialist for further diagnosis"))
        
    @Rule(Fact(action='eye_disease'),Fact(disease=MATCH.disease))
    def disease(self, disease):
        print("")
        id_disease = disease
        gui_form2 = Tk()
        gui_form2.title("eye diseases diagnosis expert system")
        lb0 = Label(gui_form2,text="",bg="#123456", fg="#fff",width="800")
        lb0.pack()
        var = StringVar()
        var.set(id_disease)
        lb1 = Label(gui_form2, textvariable = var,bg="#678954", fg="#fff",width="800")
        lb1.pack()
        print(" %s\n" %(id_disease))
        gui_form2.mainloop()

#run class
engine = eye_diesease()
while(1):
    engine.reset()  # Prepare the engine for the execution.
    engine.run()  # Run it!
    print("Would you like to diagnose some other symptoms?")
    if input() == "no":
        break;
# Out:
# WARNING:experta.watchers.ENGINE:Declaring fact before reset()
# Would you like to diagnose some other symptoms?
# no
